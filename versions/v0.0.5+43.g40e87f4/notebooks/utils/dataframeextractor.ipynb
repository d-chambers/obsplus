# %% [markdown]
# # DataFrameExtractor
#
#
# <div class="alert alert-warning">
#
# **Warning**: This section is a bit technical and many users won't need this functionality. Also, it is a bit experimental and the API may change in future versions. Proceed with caution.
#
# </div>
#
# The callables [`picks_to_df`, `events_to_df`](../datastructures/events_to_pandas.ipynb), and [`inventory_to_df`](../datastructures/stations_to_pandas.ipynb) are instances of `DataFrameExtractor`, which provides an extensible and customizable way for creating callables that extract `DataFrames` from arbitrary objects.
#
# To demonstrate, let's create a new extractor to put arrival objects in the Crandall catalog into a dataframe. We can then join this table together with the picks table to do some (possibly) interesting things.

# %%
import obspy

import obsplus

crandall = obsplus.load_dataset('crandall_test')
cat =crandall.event_client.get_events()
print(cat)
# Out:
# downloading waveform data for crandall_test dataset ...
# [2020-12-17 22:54:57,739] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-12-17 22:54:57,742] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-12-17 22:54:57,743] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-12-17 22:54:57,743] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-12-17 22:55:01,796] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (4.05 seconds)
# [2020-12-17 22:55:01,838] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-12-17 22:55:01,842] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-12-17 22:55:01,844] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 57 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-12-17 22:55:03,240] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-12-17 22:55:04,751] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 41 channels (of 50)
# [2020-12-17 22:55:04,752] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-12-17 22:55:04,801] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.4 MB [152.09 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-12-17 22:55:04,803] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-12-17 22:55:04,804] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels after downloading: DOWNLOADED
# [2020-12-17 22:55:04,967] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.P16A.xml'.
# [2020-12-17 22:55:04,974] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.O18A.xml'.
# [2020-12-17 22:55:05,023] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.O15A.xml'.
# [2020-12-17 22:55:05,121] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.P17A.xml'.
# [2020-12-17 22:55:05,169] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.P15A.xml'.
# [2020-12-17 22:55:05,212] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.O16A.xml'.
# [2020-12-17 22:55:05,320] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.P18A.xml'.
# [2020-12-17 22:55:05,336] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.Q16A.xml'.
# [2020-12-17 22:55:05,367] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.R17A.xml'.
# [2020-12-17 22:55:05,482] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' -
- obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels before downloading: EXISTS
# [2020-12-17 22:56:20,794] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-12-17 22:56:21,244] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No data available for request.
# [2020-12-17 22:56:21,245] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-12-17 22:56:21,246] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.0 MB [0.00 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-12-17 22:56:21,247] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-12-17 22:56:21,248] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels after downloading: EXISTS
# [2020-12-17 22:56:21,266] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-12-17 22:56:21,267] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-12-17 22:56:21,268] - obspy.clients.fdsn.mass_downloader - INFO: 48 MiniSEED files [0.3 MB] already existed.
# [2020-12-17 22:56:21,268] - obspy.clients.fdsn.mass_downloader - INFO: 16 StationXML files [0.4 MB] already existed.
# [2020-12-17 22:56:21,269] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-17 22:56:21,269] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-17 22:56:21,270] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.0 MB in total.
# [2020-12-17 22:56:21,334] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-12-17 22:56:21,336] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-12-17 22:56:21,337] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-12-17 22:56:21,337] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-12-17 22:56:25,281] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (3.94 seconds)
# [2020-12-17 22:56:25,323] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-12-17 22:56:25,327] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-12-17 22:56:25,329] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels before downloading: EXISTS
# [2020-12-17 22:56:25,330] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-12-17 22:56:25,797] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No data available for request.
# [2020-12-17 22:56:25,799] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-12-17 22:56:25,800] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.0 MB [0.00 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-12-17 22:56:25,800] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-12-17 22:56:25,801] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels after downloading: EXISTS
# [2020-12-17 22:56:25,821] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-12-17 22:56:25,822] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-12-17 22:56:25,823] - obspy.clients.fdsn.mass_downloader - INFO: 51 MiniSEED files [0.3 MB] already existed.
# [2020-12-17 22:56:25,823] - obspy.clients.fdsn.mass_downloader - INFO: 17 StationXML files [0.4 MB] already existed.
# [2020-12-17 22:56:25,824] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-17 22:56:25,824] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-17 22:56:25,825] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.0 MB in total.
# [2020-12-17 22:56:25,893] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-12-17 22:56:25,896] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-12-17 22:56:25,896] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-12-17 22:56:25,897] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-12-17 22:56:29,986] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (4.09 seconds)
# [2020-12-17 22:56:30,027] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-12-17 22:56:30,032] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-12-17 22:56:30,034] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels before downloading: EXISTS
# [2020-12-17 22:56:30,035] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-12-17 22:56:30,501] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No data available for request.
# [2020-12-17 22:56:30,502] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-12-17 22:56:30,503] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.0 MB [0.00 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-12-17 22:56:30,504] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-12-17 22:56:30,504] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels after downloading: EXISTS
# [2020-12-17 22:56:30,523] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-12-17 22:56:30,524] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-12-17 22:56:30,524] - obspy.clients.fdsn.mass_downloader - INFO: 48 MiniSEED files [0.3 MB] already existed.
# [2020-12-17 22:56:30,525] - obspy.clients.fdsn.mass_downloader - INFO: 16 StationXML files [0.4 MB] already existed.
# [2020-12-17 22:56:30,527] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-17 22:56:30,528] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-17 22:56:30,529] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.0 MB in total.
# finished downloading station data for crandall_test
# downloading event data for crandall_test dataset ...
# finished downloading event data for crandall_test
# 8 Event(s) in Catalog:
# 2007-08-06T08:48:40.010000Z | +39.464, -111.228 | 4.2 mb
# 2007-08-07T02:14:24.080000Z | +39.463, -111.223 | 1.17 ml
# 2007-08-07T03:44:18.470000Z | +39.462, -111.215 | 1.68 ml
# 2007-08-07T07:13:05.760000Z | +39.461, -111.224 | 2.55 ml
# 2007-08-07T02:05:04.490000Z | +39.465, -111.225 | 2.44 ml
# 2007-08-06T10:47:25.600000Z | +39.462, -111.232 | 1.92 ml
# 2007-08-07T21:42:51.130000Z | +39.463, -111.220 | 1.88 ml
# 2007-08-06T01:44:48.810000Z | +39.462, -111.238 | 2.32 ml

# %% [markdown]
# We will start by initializing the extractor with a list of expected columns and data types. This is optional, but helps ensure the output dataframe has a consistent shape and data type. The [arrival documentation](https://docs.obspy.org/packages/autogen/obspy.core.event.origin.Arrival.html) may be useful to understand these. Rather than collecting all the data contained in the `Arrival` instances, we will only create a few columns of interest.

# %%
from collections import OrderedDict

import obspy.core.event as ev

# declare datatypes (order to double as required columns)
dtypes = OrderedDict(
    resource_id=str, 
    pick_id=str, 
    event_id=str,
    origin_id= str, 
    phase=str, 
    time_correction=float, 
    distance=float, 
    time_residual=float,                
    time_weight=float,
)

# init the DataFrameExtractor
arrivals_to_df = obsplus.DataFrameExtractor(ev.Arrival, required_columns=list(dtypes), 
                                            dtypes=dtypes)

# %% [markdown]
# Next we define some "extractors". These are callables that will take an `Arrival` instance and return the desired data. The extractors can return:
#
# 1. A `dict` of values where each key corresponds to a column name and each value is the row value of that column for the current object.
#
# 2. Anything else, which is interpreted as the row value, and the column name is obtained from the function name.

# %%
# an extractor which returns a dictionary
@arrivals_to_df.extractor
def _get_basic(arrival):
    out = dict(
        resource_id=str(arrival.resource_id),
        pick_id=str(arrival.pick_id),
        time_correction=arrival.time_correction,
        distance=arrival.distance,
        time_residual=arrival.time_residual,
        time_weight=arrival.time_weight,
    )
    return out


# an extractor which returns a single value
@arrivals_to_df.extractor
def _get_phase(arrival):
    return arrival.phase

# %% [markdown]
# Notice, however, that we have no way of extracting information from the parent `Origin` or `Event` objects. Also, the extractor doesn't yet know how to find the arrivals in a `Catalog` object. To accomplish both these tasks, we can define the types of data the extractor can operate on, and inject the event and origin data into arrival rows:

# %%
@arrivals_to_df.register(obspy.Catalog)
def _get_arrivals_from_catalogs(cat):
    arrivals = []  # a list of arrivals
    extras = {}  # dict of data to inject to arrival level
    for event in cat:
        for origin in event.origins:
            arrivals.extend(origin.arrivals)
            data = dict(event_id=event.resource_id, origin_id=origin.resource_id)
            # use arrival id to inject extra to each arrival row
            extras.update({id(x): data for x in origin.arrivals})
    return arrivals_to_df(arrivals, extras=extras)

# %% [markdown]
# Great, now let's try out the extractor!

# %%
df = arrivals_to_df(cat)
df.head()
# Out:
#                                       resource_id             pick_id  \
# 0  smi:local/6a7f7180-21e5-4bbf-9a4e-20755d212437  smi:local/21691352
# 1  smi:local/5e517baf-02ec-4a33-9225-7233dc109628  smi:local/21691353
# 2  smi:local/83a9d3ca-415d-470b-93bb-34677e9f64af  smi:local/21691354
# 3  smi:local/6593b4e2-8cd1-4ea0-85d7-7c67a0759a3d  smi:local/21691355
# 4  smi:local/7ee1ae58-d3aa-442c-ad1e-ca2bd9ca56d8  smi:local/21691356
#
#            event_id         origin_id phase  time_correction  distance  \
# 0  smi:local/248839  smi:local/404328    Pg              NaN     0.384
# 1  smi:local/248839  smi:local/404328    Pg              NaN     0.356
# 2  smi:local/248839  smi:local/404328    Pg              NaN     0.550
# 3  smi:local/248839  smi:local/404328    Sg              NaN     0.384
# 4  smi:local/248839  smi:local/404328    Sg              NaN     0.356
#
#    time_residual  time_weight
# 0          0.258         -1.0
# 1          1.334         -1.0
# 2          0.158         -1.0
# 3         -1.695         -1.0
# 4          0.038         -1.0

# %%
df.phase.value_counts()
# Out:
# pPn    238
# P      224
# Pb     129
# Sb      87
# Pg      79
# S       66
# Pn      53
# Sg      53
# Sn      22
# pPb      3
# Name: phase, dtype: int64

# %% [markdown]
# Looks good, however, what if we only wanted P phases? The easiest thing to do is simply filter the dataframe, but, for demonstration, let's modify our phase extractor so that any row that is not a P phase is skipped. This is done by raising a `SkipRow` exception which is an attribute of the `DataFrameExtractor`.

# %%
@arrivals_to_df.extractor
def _get_phase(arrival):
    phase = arrival.phase
    if phase.upper() != 'P':
        raise arrivals_to_df.SkipRow
    return phase
# Out:
# /home/runner/work/obsplus/obsplus/obsplus/structures/dfextractor.py:118: UserWarning: _get_phase is already a registered extractor, overwriting
#   warnings.warn(msg)

# %%
df = arrivals_to_df(cat)
print(df.phase.value_counts())
# Out:
# P    224
# Name: phase, dtype: int64

# %% [markdown]
# Now we can get a picks dataframe and perform a left join on the phases:

# %%
# get picks and filter out non-P phases
picks = obsplus.picks_to_df(cat)
picks = picks[picks.phase_hint.str.upper() == "P"]

# %%
df_merged = df.merge(picks, how='left', right_on='resource_id', left_on='pick_id')

# %%
df_merged.head()
# Out:
#                                     resource_id_x             pick_id  \
# 0  smi:local/ed8b0924-a569-4a9b-be1a-9e837cbaf91e  smi:local/21691352
# 1  smi:local/14bccf6c-a0ec-4805-9469-a11c7704aafe  smi:local/21691353
# 2  smi:local/a1c56c67-4c6f-4f4a-af55-c886007821dc  smi:local/21691354
# 3  smi:local/4f383f7b-56d3-4305-8754-f93e26230698  smi:local/21691357
# 4  smi:local/fbb1b19a-5c2b-44bc-a4bf-7e4edfbbe1d9  smi:local/21691358
#
#          event_id_x         origin_id phase  time_correction  distance  \
# 0  smi:local/248839  smi:local/404330     P              NaN     0.319
# 1  smi:local/248839  smi:local/404330     P              NaN     0.407
# 2  smi:local/248839  smi:local/404330     P              NaN     0.585
# 3  smi:local/248839  smi:local/404330     P              NaN     0.624
# 4  smi:local/248839  smi:local/404330     P              NaN     0.755
#
#    time_residual  time_weight       resource_id_y  ... agency_id  \
# 0          0.437         -1.0  smi:local/21691352  ...
# 1         -0.705         -1.0  smi:local/21691353  ...
# 2         -1.596         -1.0  smi:local/21691354  ...
# 3         -0.518         -1.0  smi:local/21691357  ...
# 4         -0.598         -1.0  smi:local/21691358  ...
#
#          event_id_y network station  location  channel uncertainty  \
# 0  smi:local/248839      TA    P17A                BHZ         NaN
# 1  smi:local/248839      TA    P16A                BHZ         NaN
# 2  smi:local/248839      TA    Q16A                BHZ         NaN
# 3  smi:local/248839      UU     SRU                BHZ         NaN
# 4  smi:local/248839      TA    O16A                BHZ         NaN
#
#   lower_uncertainty upper_uncertainty confidence_level
# 0               NaN               NaN              NaN
# 1               NaN               NaN              NaN
# 2               NaN               NaN              NaN
# 3               NaN               NaN              NaN
# 4               NaN               NaN              NaN
#
# [5 rows x 34 columns]

# %%
df_merged.columns
# Out:
# Index(['resource_id_x', 'pick_id', 'event_id_x', 'origin_id', 'phase',
#        'time_correction', 'distance', 'time_residual', 'time_weight',
#        'resource_id_y', 'time', 'seed_id', 'filter_id', 'method_id',
#        'horizontal_slowness', 'backazimuth', 'onset', 'phase_hint', 'polarity',
#        'evaluation_mode', 'event_time', 'evaluation_status', 'creation_time',
#        'author', 'agency_id', 'event_id_y', 'network', 'station', 'location',
#        'channel', 'uncertainty', 'lower_uncertainty', 'upper_uncertainty',
#        'confidence_level'],
#       dtype='object')

# %% [markdown]
# We can also calculate how often the `phase` attribute in the arrival is different from the `phase_hint` in the pick, which could indicate a quality issue.

# %%
# calculate fraction of phase_hints that match phase
(df_merged['phase'] == df_merged['phase_hint']).sum() / len(df_merged)
# Out:
# 1.0
